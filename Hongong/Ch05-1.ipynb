# %% [markdown]
# #### 5-1 함수만들기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# def 함수 이름():
#     문장


def print_3_times():
    print("안녕하세요")
    print("안녕하세요")
    print("안녕하세요")

print_3_times()
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
# def 함수 이름(매개변수, 매개변수, ...):
#     문장

def print_n_times(value, n):
    for i in range(n):
        print(value)

print_n_times("안녕하세요", 3) # 함수를 호출할 때는 선언할 떄와 같은 개수의 매개변수 입력
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
# def 함수 이름(매개변수 배개변수, ..., *가변 배개변수):
#     문장

def print_n_times(n, *values): # n번 반복합니다 
    for i in range(n): # values는 리스트처럼 활용합니다 
        for value in values:
            print(value)
        print()

print_n_times(3, "안녕하세요", "즐거운", "파이썬 프로그래밍")
# Out:
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# %%
def print_n_times(value, n=2): # 기본 매개변수
    for i in range(n):
        print(value)
    
print_n_times("안녕하세요")
# Out:
# 안녕하세요
# 안녕하세요

# %% [markdown]
# 💡 기본 매개변수 뒤에는 일반 매개변수가 올 수 없음

# %%
def print_n_times(n=2, *values):
    for i in range(n):
        for value in values:
            print(value)
        print()

print_n_times("안녕하세요", "즐거운", "파이썬 프로그래밍")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 7
#       4             print(value)
#       5         print()
# ----> 7 print_n_times("안녕하세요", "즐거운", "파이썬 프로그래밍")
#
# Cell In[28], line 2, in print_n_times(n, *values)
#       1 def print_n_times(n=2, *values):
# ----> 2     for i in range(n):
#       3         for value in values:
#       4             print(value)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %% [markdown]
# 기본 매개변수가 가변 매개변수보다 앞에 올 때는 기본 매개변수의 의미가 사라짐

# %%
def print_n_times(*values, n=2):
    for i in range(n):
        for value in values:
            print(value)
        print()

print_n_times("안녕하세요", "즐거운", "파이썬 프로그래밍", 3)
# Out:
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
# 3
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
# 3

# %% [markdown]
# 가변 매개변수가 기본 매개변수보다 앞에 오면 가변 매개변수가 우선됨

# %%
def print_n_times(*values, n=2):
    for i in range(n):
        for value in values:
            print(value)
        print()

print_n_times("안녕하세요", "즐거운", "파이썬 프로그래밍", n=2) # 키워드 매개변수
# Out:
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# %%
def test(a, b=10, c=100):
    print(a + b + c)

# 1) 기본 형태 
test(10, 20, 30)
# 2) 키워드 매개변수로 모든 매개변수를 지정한 형태 
test(a=10, b=100, c=200)
# 3) 키워드 매개변수로 모든 매개변수를 마구잡이로 지정된 형태 
test(c=10, a=100, b=200)
# 4) 키워드 매개변수로 일부 매개변수만 지정한 형태
test(10, c=200)
# Out:
# 60
# 310
# 310
# 220

# %% [markdown]
# return : 함수를 실행했던 위치로 돌아가라는 뜻으로, 함수가 끝나는 위치를 의미

# %%
# input() 함수의 리턴값을 변수에 저장
value = input("> ")

print(value)
# Out:
# 123

# %%
# 자료 없이 리턴
def return_test():
    print("A 위치입니다.")
    return
    print("B 위치입니다.")

return_test()
# Out:
# A 위치입니다.

# %%
# 자료와 함께 리턴
def return_test():
    return 100

value = return_test()
print(value)
# Out:
# 100

# %%
# 아무 것도 리턴하지 않기 
def return_test():
    return

value = return_test()
print(value)
# Out:
# None

# %%
# 범위 내부의 정수를 모두 더하는 함수 

def sum_all(start,end):
    output = 0
     
    for i in range(start, end + 1):
        output += i
    return output

print("0 to 100:", sum_all(0,100))
print("0 to 1000:", sum_all(0,1000))
print("50 to 100:", sum_all(50,100))
print("500 to 1000:", sum_all(500,1000))
# Out:
# 0 to 100: 5050
# 0 to 1000: 500500
# 50 to 100: 3825
# 500 to 1000: 375750

# %%
# 기본 매개변수와 키워드 매개변수를 활용해 범위의 정수를 더하는 함수 

def sum_all(start=0, end=100, step=1):
    output = 0
     
    for i in range(start, end + 1, step):
        output += i
    return output

print("A.", sum_all(0,100,10))
print("B.", sum_all(end=100))
print("C.", sum_all(end=100, step=2))
# Out:
# A. 550
# B. 5050
# C. 2550

# %% [markdown]
# 💡 초깃값을 설정할 때는 연산에 아무런 변화를 주지 않는 것을 사용 (덧셈식은 0, 곱셈식은 1)

# %%
# 매개변수로 전달된 값들을 모두 곱해서 리턴하는 가변 매개변수 함수 만들기
def mul (*values):
    output = 1

    for value in values:
        output *= value
    return output

print(mul(5, 7, 9, 10))
# Out:
# 3150

# %%
def function(*values, valueA, valueB): 
    pass
function(1, 2, 3, 4, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 def function(*values, valueA, valueB): #
#       2     pass
# ----> 3 function(1, 2, 3, 4, 5)
#
# TypeError: function() missing 2 required keyword-only arguments: 'valueA' and 'valueB'
