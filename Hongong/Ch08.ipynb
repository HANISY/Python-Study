# %% [markdown]
# ### 8. 클래스

# %% [markdown]
# #### 8-1. 클래스의 기본

# %% [markdown]
# - **객체 지향 프로그래밍 (OOP, Object-Oriented Programming)**
#
#     **"현실 세계를 소프트웨어로 모델링하는 방법론"**
#
#     프로그램을 단순히 데이터와 처리 방법으로 나누는 것이 아니라, 수많은 **'객체(Object)'** 라는 기본 단위로 나누고 이들의 상호작용으로 서술
#
#     - 객체(Object): 데이터(속성)와 그 데이터를 처리하는 코드(메서드)를 하나로 묶은 독립적인 단위
#
#     - 재사용성: 이미 만들어진 객체(모듈)를 다른 프로젝트에서도 쉽게 가져다 쓸 수 있음
#
#     - 유지보수성: 문제가 발생했을 때, 전체를 뜯어고칠 필요 없이 해당 객체(부품)만 수리하거나 교체하면 됨
#
# - **추상화 (Abstraction)**
#
#     **"불필요한 세부 사항은 숨기고, 핵심적인 특징만 간추리는 과정"**
#
#     - 일반화: 여러 객체에서 공통적으로 사용되는 속성과 기능을 추출하여 상위 개념(클래스)으로 정의
#
#     - 복잡도 관리: 구체적인 로직은 내부에 감추고, 외부에는 간단한 인터페이스(사용법)만 노출

# %% [markdown]
# ##### 객체
#
# 여러 가지 속성을 가질 수 있는 대상

# %%
# 객체 만들기
# 학생 리스트 선언
students = [
    {"name": "윤인성", "korean" : 87, "math" : 98, "english" : 88, "science" : 95},
    {"name": "연하진", "korean" : 92, "math" : 98, "english" : 96, "science" : 98},
    {"name": "구지연", "korean" : 76, "math" : 96, "english" : 94, "science" : 90},
    {"name": "나선주", "korean" : 98, "math" : 92, "english" : 96, "science" : 92},
    {"name": "윤아린", "korean" : 95, "math" : 98, "english" : 98, "science" : 98},
    {"name": "윤명월", "korean" : 64, "math" : 88, "english" : 92, "science" : 92}
]

# 학생 한명씩 반복
print("이름", "총점", "평균", sep="\t")
for student in students:
    # 점수의 총합과 평균 구하기
    score_sum = student["korean"] + student["math"] +\
        student["english"] + student["science"]
    score_average = score_sum / 4
    # 출력
    print(student["name"], score_sum, score_average, sep="\t")
# Out:
# 이름	총점	평균
# 윤인성	368	92.0
# 연하진	384	96.0
# 구지연	356	89.0
# 나선주	378	94.5
# 윤아린	389	97.25
# 윤명월	336	84.0

# %%
# 객체를 만드는 함수(1)
# 딕셔너리를 리턴하는 함수 선언
def create_student(name, korean, math, english, science):
    return {
        "name": name,
        "korean": korean,
        "math": math,
        "english": english,
        "science": science
    }

# 학생 리스트 선언
students = [
    create_student("윤인성", 87, 98, 88, 95),
    create_student("연하진", 92, 98, 96, 98),
    create_student("구지연", 76, 96, 94, 90),
    create_student("나선주", 98, 92, 96, 92),
    create_student("윤아린", 95, 98, 98, 98),
    create_student("윤명월", 64, 88, 92, 92)
]

# 학생을 한 명씩 반복
print("이름", "총점", "평균", sep="\t")
for student in students:
    # 점수의 총합과 평균 구하기
    score_sum = student["korean"] + student["math"] +\
        student["english"] + student["science"]
    score_average = score_sum / 4
    # 출력
    print(student["name"], score_sum, score_average, sep="\t")
# Out:
# 이름	총점	평균
# 윤인성	368	92.0
# 연하진	384	96.0
# 구지연	356	89.0
# 나선주	378	94.5
# 윤아린	389	97.25
# 윤명월	336	84.0

# %%
# 객체를 만드는 함수(2)
# 딕셔너리를 리턴하는 함수 선언
def create_student(name, korean, math, english, science):
    return {
        "name": name,
        "korean": korean,
        "math": math,
        "english": english,
        "science": science
    }

# 학생을 처리하는 함수 선언
def student_get_sum(student):
    return student["korean"] + student["math"] +\
        student["english"] + student["science"]
def student_get_average(student):
    return student_get_sum(student) / 4

def student_to_string(student):
  return "{}\t{}\t{}".format(
      student["name"],
      student_get_sum(student),
      student_get_average(student))

# 학생 리스트 선언
students = [
    create_student("윤인성", 87, 98, 88, 95),
    create_student("연하진", 92, 98, 96, 98),
    create_student("구지연", 76, 96, 94, 90),
    create_student("나선주", 98, 92, 96, 92),
    create_student("윤아린", 95, 98, 98, 98),
    create_student("윤명월", 64, 88, 92, 92)
]

# 학생을 한 명씩 반복
print("이름", "총점", "평균", sep="\t")
for student in students:
    print(student_to_string(student))
# Out:
# 이름	총점	평균
# 윤인성	368	92.0
# 연하진	384	96.0
# 구지연	356	89.0
# 나선주	378	94.5
# 윤아린	389	97.25
# 윤명월	336	84.0

# %% [markdown]
# 객체와 관련된 코드를 분리할 수 있게 하는 것이 객체 지향 프로그래밍의 핵심

# %% [markdown]
# ---

# %% [markdown]
# ##### 클래스 선언하기

# %% [markdown]
# 파이썬의 명명 규칙 - **클래스: 파스칼 케이스**
#
# - 규칙: 각 단어의 첫 글자를 대문자로 표기하며, 단어 사이의 연결에 언더바(_)를 사용하지 않음
#
# - 사용 이유: 이 이름이 단순한 데이터나 함수가 아니라, **'객체를 찍어내는 틀(Class)'** 임을 명시하기 위함
#
# - 예시: Student, ScreamingSnakeCase, MyClass

# %% [markdown]
# ```python
# 인스턴스 이름(변수 이름) = 클래스 이름()

# %% [markdown]
# 인스턴스: 클래스를 기반으로 만들어진 객체

# %% [markdown]
# ---

# %% [markdown]
# ##### 생성자
#
# 클래스 이름과 같은 함수

# %% [markdown]
# ```python
# class 클래스 이름:
#   def __init__(self, 추가적인 매개변수):
#     pass

# %% [markdown]
# 소멸자: 인스턴스가 소멸될 때 호출되는 함수
#
# ```python
# class Test:
# def __init__(self, name):
#   self.name = name
#   print("{} - 생성되었습니다".format(self.name))
# def __del__(self):
#   print("{} - 파괴되었습니다".format(self.name))
# ```
#
# A - 생성되었습니다 </br>
# A - 파괴되었습니다

# %% [markdown]
# ```python
# # 클래스 선언
# class Student:
#   def __init__(self, name, korean, math, english, science):
#     self.name = name,
#     self.korean = korean,
#     self.math = math,
#     self.english = english,
#     self.science = science
#
# # 학생 리스트 선언
# students = [
#     Student("윤인성", 87, 98, 88, 95),
#     Student("연하진", 92, 98, 96, 98),
#     Student("구지연", 76, 96, 94, 90),
#     Student("나선주", 98, 92, 96, 92),
#     Student("윤아린", 95, 98, 98, 98),
#     Student("윤명월", 64, 88, 92, 92)
# ]
#
# # Student 인스턴스 속성에 접근하는 방법
# students[0].name
# students[0].korean
# students[0].math
# students[0].english
# students[0].science
# ```
#
# Student 인스턴스가 생성될 때 속성이 직접 추가됨

# %% [markdown]
# ---

# %% [markdown]
# ##### 메소드
#
# 클래스가 가지고 있는 함수
#
# ```python
# class 클래스 이름:
#   def 메소드 이름(self, 추가적인 매개변수):
#     pass

# %%
# 클래스 내부에 함수(메소드) 선언하기
# 클래스 선언
class Student:
  def __init__(self, name, korean, math, english, science):
    self.name = name
    self.korean = korean
    self.math = math
    self.english = english
    self.science = science

  def get_sum(self):
      return self.korean + self.math +\
          self.english + self.science

  def get_average(self):
      return self.get_sum() / 4

  def to_string(self):
    return "{}\t{}\t{}".format(\
      self.name,\
      self.get_sum(),\
      self.get_average())

# 학생 리스트 선언
students = [
    Student("윤인성", 87, 98, 88, 95),
    Student("연하진", 92, 98, 96, 98),
    Student("구지연", 76, 96, 94, 90),
    Student("나선주", 98, 92, 96, 92),
    Student("윤아린", 95, 98, 98, 98),
    Student("윤명월", 64, 88, 92, 92)
]

# 학생을 한 명씩 반복
print("이름", "총점", "평균", sep="\t")
for student in students:
  print(student.to_string())
# Out:
# 이름	총점	평균
# 윤인성	368	92.0
# 연하진	384	96.0
# 구지연	356	89.0
# 나선주	378	94.5
# 윤아린	389	97.25
# 윤명월	336	84.0

# %% [markdown]
# ---

# %% [markdown]
# #### 8-2. 클래스의 추가적인 구문

# %% [markdown]
# ##### 어떤 클래스의 인스턴스인지 확인하기
# ```python
# isintance(인스턴스, 클래스)
# ```
# 해당 클래스를 기반으로 만들어졌다면 True, 전혀 상관이 없는 인스턴스와 클래스라면 False를 리턴

# %%
# 클래스 선언
class Student:
  def __init__(self):
    pass

# 학생 선언
student = Student()

# 인스턴스 확인
print("isinstance(student, Student):", isinstance(student, Student))
# Out:
# isinstance(student, Student): True

# %%
# isinstance() 함수와 type() 함수로 확인하는 것의 차이
# 클래스 선언
class Human:
  def __init__(self):
    pass
class Student(Human):
  def __init__(self):
    pass

# 학생 선언
student = Student()

# 인스턴스 확인
print("isinstance(student, Human):", isinstance(student, Human))
print("type(student) == Human:", type(student) == Human)
# Out:
# isinstance(student, Human): True
# type(student) == Human: False

# %% [markdown]
# Student 클래스는 Human 클래스를 상속받아서 만듦
#
# isinstance() 함수는 이러한 상속관계까지 확인
#
# 반면, type() 함수는 이러한 상속관계를 확인하지 않음

# %%
# instance() 함수 확용
# 학생 클래스 선언
class Student:
  def study(self):
    print("공부를 합니다.")

# 선생님 클래스 선언
class Teacher:
  def teach(self):
    print("학생을 가르칩니다.")

# 교실 내부 객체 리스트 생성
classroom = [Student(), Student(), Teacher(), Student(), Student()]

# 반복을 적용해서 적절한 함수를 호출
for person in classroom:
  if isinstance(person, Student):
    person.study()
  elif isinstance(person, Teacher):
    person.teach()
# Out:
# 공부를 합니다.
# 공부를 합니다.
# 학생을 가르칩니다.
# 공부를 합니다.
# 공부를 합니다.

# %% [markdown]
# ##### 특수한 이름의 메소드

# %%
# __str__() 함수
# 클래스 선언
class Student:
  def __init__(self, name, korean, math, english, science):
    self.name = name
    self.korean = korean
    self.math = math
    self.english = english
    self.science = science

  def get_sum(self):
    return self.korean + self.math +\
        self.english + self.science

  def get_average(self):
    return self.get_sum() / 4

  def __str__(self):
    return "{}\t{}\t{}".format(\
      self.name,\
      self.get_sum(),\
      self.get_average())

# 학생 리스트 선언
students = [
    Student("윤인성", 87, 98, 88, 95),
    Student("연하진", 92, 98, 96, 98),
    Student("구지연", 76, 96, 94, 90),
    Student("나선주", 98, 92, 96, 92),
    Student("윤아린", 95, 98, 98, 98),
    Student("윤명월", 64, 88, 92, 92)
]

# 출력
print("이름", "총점", "평균", sep="\t")
for student in students:
  print(str(student))
# Out:
# 이름	총점	평균
# 윤인성	368	92.0
# 연하진	384	96.0
# 구지연	356	89.0
# 나선주	378	94.5
# 윤아린	389	97.25
# 윤명월	336	84.0

# %% [markdown]
# 크기를 비교하는 함수 이름
#
# |이름|영어|설명|
# |:---:|---|---|
# |eq|equal|같다|
# |ne|not equal|다르다|
# |gt|greater than|크다|
# |ge|greater than or equal|크거나 같다|
# |lt|less than|작다|
# |le|less than or equal|작거나 같다|

# %%
# 크기 비교 함수
# 클래스 선언
class Student:
  def __init__ (self, name, korean, math, english, science):
    self.name = name
    self.korean = korean
    self.math = math
    self.english = english
    self.science = science

  def get_sum(self):
    return self.korean + self.math +\
      self.english + self.science

  def get_average(self):
    return self.get_sum() / 4

  def __str__ (self):
    return "{}\t{}\t{}".format(
        self.name,
        self.get_sum(),
        self.get_average()
    )

  def __eq__ (self, value):
    return self.get_sum() == value.get_sum()
  def __ne__ (self, value):
    return self.get_sum() !=  value.get_sum()
  def __gt__ (self, value):
    return self.get_sum() > value.get_sum()
  def __ge__ (self, value):
    return self.get_sum() >= value.get_sum()
  def __lt__ (self, value):
    return self.get_sum() < value.get_sum()
  def __le__ (self, value):
    return self.get_sum() <= value.get_sum()



# 학생 선언
student_a = Student("윤인성", 87, 98, 88, 95),
student_b = Student("연하진", 92, 98, 96, 98),

# 출력
print("student_a == student_b = ", student_a == student_b)
print("student_a != student_b = ", student_a != student_b)
print("student_a > student_b = ", student_a > student_b)
print("student_a >= student_b = ", student_a >= student_b)
print("student_a < student_b = ", student_a < student_b)
print("student_a <= student_b = ", student_a <= student_b)
# Out:
# student_a == student_b =  False
# student_a != student_b =  True
# student_a > student_b =  False
# student_a >= student_b =  False
# student_a < student_b =  True
# student_a <= student_b =  True

# %% [markdown]
# 프로그래밍을 할 때는 항상 다른 사람과 함께 한다는 협업의 관점에서 함수를 사용하는 것이 좋음

# %% [markdown]
# ---

# %% [markdown]
# ##### 클래스 변수와 메소드

# %% [markdown]
# 클래스 변수 만들기
# ```python
# class 클래스 이름:
#   클래스 변수 = 값
# ```
#
# 클래스 변수에 접근하기
# ```python
# 클래스 이름.변수 이름
# ```

# %%
# 클래스 변수
# 클래스 선언
class Student:
  count = 0

  def __init__(self, name, korean, math, english, science):
    # 인스턴스 변수 초기화
    self.name = name
    self.korean = korean
    self.math = math
    self.english = english
    self.science = science

    # 클래스 변수 설정
    Student.count += 1
    print("{}번째 학생이 생성되었습니다.".format(Student.count))

# 학생 리스트 선언
students = [
    Student("윤인성", 87, 98, 88, 95),
    Student("연하진", 92, 98, 96, 98),
    Student("구지연", 76, 96, 94, 90),
    Student("나선주", 98, 92, 96, 92),
    Student("윤아린", 95, 98, 98, 98),
    Student("윤명월", 64, 88, 92, 92)
]

# 출력
print()
print("현재 생성된 총 학생 수는 {}명입니다.".format(Student.count))
# Out:
# 1번째 학생이 생성되었습니다.
# 2번째 학생이 생성되었습니다.
# 3번째 학생이 생성되었습니다.
# 4번째 학생이 생성되었습니다.
# 5번째 학생이 생성되었습니다.
# 6번째 학생이 생성되었습니다.
#
# 현재 생성된 총 학생 수는 6명입니다.

# %% [markdown]
# 클래스 함수 만들기
# ```python
# class 클래스 이름:
#   @classmethod
#   def 클래스 함수(cls, 매개변수):
#     pass
# ```
#
# 클래스 함수 호출하기
# ```python
# 클래스 이름.함수 이름(매개변수)
# ```

# %%
# 클래스 함수
# 클래스 선언
class Student:
  # 클래스 변수
  count = 0
  students = []

  # 클래스 함수
  @classmethod
  def print(cls):
    print("---- 학생 목록 ----")
    print("이름\t총점\t평균")
    for student in cls.students:
      print(str(student))
    print("------ ------ ------")

  # 인스턴스 함수
  def __init__(self, name, korean, math, english, science):
    self.name = name
    self.korean = korean
    self.math = math
    self.english = english
    self.science = science
    Student.count += 1
    Student.students.append(self)

  def get_sum(self):
    return self.korean + self.math + self.english + self.science

  def get_average(self):
    return self.get_sum() / 4

  def __str__(self):
    return "{}\t{}\t{}".format(
        self.name,
        self.get_sum(),
        self.get_average()
    )

# 학생 리스트 선언
students = [
    Student("윤인성", 87, 98, 88, 95),
    Student("연하진", 92, 98, 96, 98),
    Student("구지연", 76, 96, 94, 90),
    Student("나선주", 98, 92, 96, 92),
    Student("윤아린", 95, 98, 98, 98),
    Student("윤명월", 64, 88, 92, 92),
    Student("김미화", 82, 86, 98, 88),
    Student("김연화", 88, 74, 78, 92),
    Student("박아현", 97, 92, 88, 95),
    Student("서준서", 45, 52, 72, 78)
]

# 출력
Student.print()
# Out:
# ---- 학생 목록 ----
# 이름	총점	평균
# 윤인성	368	92.0
# 연하진	384	96.0
# 구지연	356	89.0
# 나선주	378	94.5
# 윤아린	389	97.25
# 윤명월	336	84.0
# 김미화	354	88.5
# 김연화	332	83.0
# 박아현	372	93.0
# 서준서	247	61.75
# ------ ------ ------

# %% [markdown]
# ---

# %% [markdown]
# #### 좀 더 알아보기

# %% [markdown]
# ##### 가비지 컬렉터

# %% [markdown]
# **가비지 컬렉터 (Garbage Collector, GC)**
#
# 자바, 파이썬 등 여러 고급 언어에서 채택하고 있는 자동 메모리 관리 시스템
#
# 개발자가 메모리를 수동으로 해제할 필요 없이 시스템이 스스로 처리하도록 하여 메모리 관련 오류를 줄이는 것이 주된 목적
#
# **스왑 (Swap / Swapping)**
#
# 스왑은 운영체제(OS)가 시스템의 물리 메모리(RAM) 용량의 한계를 극복하기 위해 사용하는 가상 메모리관리 기법

# %%
# 가비지 컬렉터: 변수에 저장하지 않은 경우
class Test:
  def __init__(self, name):
    self.name = name
    print("{} - 생성되었습니다.".format(self.name))
  def __del__(self):
    print("{} - 파괴되었습니다.".format(self.name))

Test("A")
Test("B")
Test("C")
# Out:
# A - 생성되었습니다.
# A - 파괴되었습니다.
# B - 생성되었습니다.
# B - 파괴되었습니다.
# C - 생성되었습니다.

# %%
# 가비지 컬렉터: 변수에 저장한 경우
class Test:
  def __init__(self, name):
    self.name = name
    print("{} - 생성되었습니다.".format(self.name))
  def __del__(self):
    print("{} - 파괴되었습니다.".format(self.name))

a = Test("A")
b = Test("B")
c = Test("C")
# Out:
# A - 생성되었습니다.
# B - 생성되었습니다.
# C - 생성되었습니다.

# %% [markdown]
# ---

# %% [markdown]
# ##### 프라이빗 변수와 게터/세터

# %%
# 원의 둘레와 넓이를 구하는 객체 지향 프로그램
import math

# 클래스 선언
class Circle:
  def __init__(self, radius):
    self.radius = radius
  def get_circumference(self):
    return 2 * math.pi * self.radius
  def get_area(self):
    return math.pi * (self.radius ** 2)

# 원의 둘레와 넓이 계산
circle = Circle(10)
print("원의 둘레:", circle.get_circumference())
print("원의 넓이:", circle.get_area())
# Out:
# 원의 둘레: 62.83185307179586
# 원의 넓이: 314.1592653589793

# %% [markdown]
# **프라이빗 변수**
#
# 클래스 내부의 변수를 외부에서 사용하는 것을 막고 싶을 때 인스턴스 변수 이름을 **__<변수 이름>** 형태로 선언

# %%
# 프라이빗 변수
# 클래스 선언
class Circle:
  def __init__(self, radius):
    self.__radius = radius
  def get_circumference(self):
    return 2 * math.pi * self.__radius
  def get_area(self):
    return math.pi * (self.__radius ** 2)

# 원의 둘레와 넓이 계산
circle = Circle(10)
print("# 원의 둘레와 넓이를 구합니다.")
print("원의 둘레:", circle.get_circumference())
print("원의 넓이:", circle.get_area())
print()

# __radius에 접근
print("# __radius에 접근합니다.")
print(circle.__radius)
# Out:
# # 원의 둘레와 넓이를 구합니다.
# 원의 둘레: 62.83185307179586
# 원의 넓이: 314.1592653589793
#
# # __radius에 접근합니다.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 20
#      18 # __radius에 접근
#      19 print("# __radius에 접근합니다.")
# ---> 20 print(circle.__radius)
#
# AttributeError: 'Circle' object has no attribute '__radius'

# %% [markdown]
# **게터와 세터**
#
# 프라이빗 변수의 값을 추출하거나 변경할 목적으로, 간접적으로 속성에 접근하도록 해주는 함수
#
# 파이썬에서는 게터를 만들지 않으면 세터를 만들 수 없음

# %%
# 클래스 선언
class Circle:
  def __init__(self, radius):
    self.__radius = radius
  def get_circumference(self):
    return 2 * math.pi * self.__radius
  def get_area(self):
    return math.pi * (self.__radius ** 2)

  # 게터와 세터를 선언
  def get_radius(self):
    return self.__radius
  def set_radius(self, value):
    self.__radius = value

# 원의 둘레와 넓이 계산
circle = Circle(10)
print("# 원의 둘레와 넓이를 구합니다.")
print("원의 둘레:", circle.get_circumference())
print("원의 넓이:", circle.get_area())
print()

# 간접적으로 __radius에 접근
print("# __radius에 접근합니다.")
print(circle.get_radius())
print()

# 원의 둘레와 넓이 계산
circle = Circle(2)
print("# 반지름을 변경하고 원의 둘레와 넓이를 구합니다.")
print("원의 둘레:", circle.get_circumference())
print("원의 넓이:", circle.get_area())
print()
# Out:
# # 원의 둘레와 넓이를 구합니다.
# 원의 둘레: 62.83185307179586
# 원의 넓이: 314.1592653589793
#
# # __radius에 접근합니다.
# 10
#
# # 반지름을 변경하고 원의 둘레와 넓이를 구합니다.
# 원의 둘레: 12.566370614359172
# 원의 넓이: 12.566370614359172

# %% [markdown]
# 게터 세터로 변수를 안전하게 사용하기
# ```python
# def set_radius(self, value):
#   if value <= 0:
#     raise TypeError("길이는 양의 숫자여야 합니다.")
#   self.__radius == value
# ```

# %%
# 데코레이터를 사용해 게터와 세터 만들기
# 클래스 선언
class Circle:
  def __init__(self, radius):
    self.__radius = radius
  def get_circumference(self):
    return 2 * math.pi * self.__radius
  def get_area(self):
    return math.pi * (self.__radius ** 2)

  # 게터와 세터 선언
  @property
  def radius(self):
    return self.__radius
  @radius.setter
  def radius(self, value):
    if value <= 0:
      raise TypeError("길이는 양의 숫자여야 합니다.")
    self.__radius = value

# 원의 둘레와 넓이 계산
print("# 데코레이터를 사용한 Getter와 Setter")
circle = Circle(10)
print("원래 원의 반지름: ", circle.radius)
circle.radius = 2
print("변경된 원의 반지름: ", circle.radius)
print()

# 강제로 예외 발생
print("# 강제로 예외를 발생시킵니다.")
circle.radius = -10
# Out:
# # 데코레이터를 사용한 Getter와 Setter
# 원래 원의 반지름:  10
# 변경된 원의 반지름:  2
#
# # 강제로 예외를 발생시킵니다.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 31
#      29 # 강제로 예외 발생
#      30 print("# 강제로 예외를 발생시킵니다.")
# ---> 31 circle.radius = -10
#
# Cell In[17], line 18, in Circle.radius(self, value)
#      15 @radius.setter
#      16 def radius(self, value):
#      17   if value <= 0:
# ---> 18     raise TypeError("길이는 양의 숫자여야 합니다.")
#      19   self.__radius = value
#
# TypeError: 길이는 양의 숫자여야 합니다.

# %% [markdown]
# ---

# %% [markdown]
# ##### 상속

# %% [markdown]
# **상속**
#
# - 기존에 정의된 클래스의 속성(데이터)과 메서드(기능)를 새로운 클래스가 그대로 물려받아 사용할 수 있도록 하는 OOP의 기본 원칙
# - 중복되는 코드를 줄이고, 모듈 간의 관계를 명확히 하여 프로그램의 유지보수성을 높이는 것이 목적
#
# **다중 상속**
#
# 하나의 자식 클래스가 두 개 이상의 부모 클래스로부터 속성과 메서드를 동시에 물려받는 상속 기법

# %% [markdown]
# **부모 클래스 vs. 자식 클래스**
# |구분|용어|역할|
# |-----|-----|-----|
# |제공자|부모 클래스 또는 상위 클래스|물려줄 기본 기능을 정의하는 기존 클래스|
# |수혜자|자식 클래스 또는 하위 클래스|부모 클래스의 기능을 물려받아 확장하거나 재정의하는 새로운 클래스|

# %%
# 상속의 활용
# 부모 클래스 선언
class Parent:
  def __init__(self):
    self.value = "테스트"
    print("Parent 클래스의 __init()__ 메소드가 호출되었습니다.")
  def test(self):
    print("Parent 클래스의 test() 메소드입니다.")

# 자식 클래스 선언
class Child(Parent):
  def __init__(self):
    super().__init__()
    print("Child 클래스의 __init()__ 메소드가 호출되었습니다.")

# 자식 클래스의 인스턴스를 생성하고 부모의 메소드를 호출합니다.
child = Child()
child.test()
print(child.value)
# Out:
# Parent 클래스의 __init()__ 메소드가 호출되었습니다.
# Child 클래스의 __init()__ 메소드가 호출되었습니다.
# Parent 클래스의 test() 메소드입니다.
# 테스트

# %% [markdown]
# ```python
# # 사용자 정의 예외 클래스 만들기
# class CustomException(Exception):
#   def __init__(self):
#     super().__init__()
#
# raise CustomException
# ```

# %%
# 자식 클래스로써 부모의 함수 재정의(오버라이드)하기
class CustomException(Exception):
  def __init__(self):
    super().__init__()
    print("##### 내가 만든 오류가 생성되었어요! #####")
  def __str__(self):
    return "오류가 발생했어요"

raise CustomException
# Out:
# ##### 내가 만든 오류가 생성되었어요! #####
# ---------------------------------------------------------------------------
# CustomException                           Traceback (most recent call last)
# Cell In[19], line 9
#       6   def __str__(self):
#       7     return "오류가 발생했어요"
# ----> 9 raise CustomException
#
# CustomException: 오류가 발생했어요

# %% [markdown]
# **재정의 또는 오버라이드**
#
# 메서드 재정의란 자식 클래스가 부모 클래스로부터 상속받은 메서드를 자신의 필요에 맞게 내용만 수정하여 다시 구현하는 기법

# %%
# 자식 클래스로써 부모에 없는 새로운 함수 정의하기
class CustomException(Exception):
  def __init__(self, message, value):
    super().__init__()
    self.message = message
    self.value = value

  def __str__(self):
    return self.message

  def print(self):
    print("##### 오류 정보 #####")
    print("메시지:", self.message)
    print("값:", self.value)

# 예외 발생
try:
  raise CustomException("딱히 이유 없음", 273)
except CustomException as e:
  e.print()
# Out:
# ##### 오류 정보 #####
# 메시지: 딱히 이유 없음
# 값: 273

# %% [markdown]
# #### 도전 문제

# %% [markdown]
# ##### 1. Student 클래스 구현하기

# %% [markdown]
# **IS-A 관계**
#
# - **상속**을 통해 구현
#
#   자식 클래스가 부모 클래스의 한 종류임을 의미
#
# - '~은 ~의 일종이다'라는 논리적 관계를 나타냄
#
# - 코드 재사용성과 다형성을 확보
#
# **HAS-A 관계**
#
# - **구성**을 통해 구현
#
# - '~은 ~을 가지고 있다'라는 포함 관계를 나타냄
#
# - 한 클래스가 다른 클래스의 인스턴스를 소유하고 있어, 해당 인스턴스의 기능을 위임받아 사용함을 의미
#
# - 캡슐화를 강화하고 클래스 간의 의존성을 낮춰 결합도를 낮춤

# %%
class Student:
  def __init__(self, name, score):
    self.name = name
    self.score = score

class StudentList:
  def __init__(self):
    # 구성 사용
    self.students = []

  def append(self,student):
    self.students.append(student)

  def get_average(self):
    return sum([student.score for student in self.students]) / len(self.students)

  def get_first_by_score(self):
    return max(self.students, key=lambda student: student.score).name   # lambda 표현식의 결과가 곧 함수의 리턴 값이 됨

  def get_last_by_score(self):
    return min(self.students, key=lambda student: student.score).name

students = StudentList()
students.append(Student("구름", 100))
students.append(Student("별", 49))
students.append(Student("초코", 81))
students.append(Student("아지", 90))

print(f"학급의 평균 점수는 {students.get_average()}입니다.")
print(f"가장 성적이 높은 학생은 {students.get_first_by_score()}입니다.")
print(f"가장 성적이 낮은 학생은 {students.get_last_by_score()}입니다.")
# Out:
# 학급의 평균 점수는 80.0입니다.
# 가장 성적이 높은 학생은 구름입니다.
# 가장 성적이 낮은 학생은 별입니다.

# %% [markdown]
# ##### 2. 스택 구현하기

# %% [markdown]
# |자료 구조|규칙|삽입 동작|삭제 동작|접근 위치|
# |---|---|---|---|---|
# |스택 (Stack)|LIFO (Last-In, First-Out)|푸시 (Push)|팝 (Pop)|맨 위|
# |큐 (Queue)|FIFO (First-In, First-Out)|푸시 / 인큐 (Enqueue)|팝 / 디큐 (Dequeue)|삽입: 맨 뒤 / 삭제: 맨 앞|

# %%
class Stack:
  def __init__(self):
    self.list = []

  def push(self, item):
    self.list.append(item)

  def pop(self):
    return self.list.pop()

stack = Stack()
stack.push(10)
stack.push(20)
stack.push(30)

print(stack.pop())
print(stack.pop())
print(stack.pop())
# Out:
# 30
# 20
# 10

# %% [markdown]
# ##### 3. 큐 구현하기

# %%
class Queue:
  def __init__(self):
    self.list = []

  def enqueue(self, item):
    self.list.append(item)

  def dequeue(self):
    return self.list.pop(0)     # pop(0) 가장 앞에 있는 요소부터

queue = Queue()
queue.enqueue(10)
queue.enqueue(20)
queue.enqueue(30)

print(queue.dequeue())
print(queue.dequeue())
print(queue.dequeue())
# Out:
# 10
# 20
# 30
