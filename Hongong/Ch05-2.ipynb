# %% [markdown]
# ### 5. 함수
# #### 5-2. 함수의 활용

# %%
# 반복문으로 팩토리얼 구하기 

def factorial(n):
    output = 1              # 곱셉은 1

    for i in range(1, n + 1):
        output *= i

    return output

print("1!:", factorial(1))
print("2!:", factorial(2))
print("3!:", factorial(3))
print("4!:", factorial(4))
print("5!:", factorial(5))
# Out:
# 1!: 1
# 2!: 2
# 3!: 6
# 4!: 24
# 5!: 120

# %%
# 재귀함수로 팩토리얼 구하기 

def factorial(n):

    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
    
print("1!:", factorial(1))
print("2!:", factorial(2))
print("3!:", factorial(3))
print("4!:", factorial(4))
print("5!:", factorial(5))
# Out:
# 1!: 1
# 2!: 2
# 3!: 6
# 4!: 24
# 5!: 120

# %% [markdown]
# 재귀 함수는 상황에 따라 같은 것을 기하급수적으로 많이 반복한다는 문제가 있음

# %%
# 재귀함수로 구현한 피보나치 수열(1)

def fibonacci(n):
    if n == 1:
        return 1
    if n == 2:
        return 1
    else: 
        return fibonacci(n - 1) + fibonacci(n - 2)
    
print("fibonacci(1):", fibonacci(1))
print("fibonacci(2):", fibonacci(2))
print("fibonacci(3):", fibonacci(3))
print("fibonacci(4):", fibonacci(4))
print("fibonacci(5):", fibonacci(5))
# Out:
# fibonacci(1): 1
# fibonacci(2): 1
# fibonacci(3): 2
# fibonacci(4): 3
# fibonacci(5): 5

# %%
# 재귀 함수로 구현한 피보나치 수열(2)

counter = 0 

def fibonacci(n):
    print("fibonacci({})를 구합니다.".format(n))
    global counter                  # 실행하는 파이썬 전체에서 사용 가능한 변수 
    counter += 1

    if n == 1: 
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)
    
fibonacci(10)
print("---")
print("fibonacci(10) 계산할 때 함수를 호출한 횟수는 {}번입니다.".format(counter))
# Out:
# fibonacci(10)를 구합니다.
# fibonacci(9)를 구합니다.
# fibonacci(8)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# ...

# %% [markdown]
# 트리구조
#
# ![image.png](attachment:image.png)

# %%
# 재귀 함수로 구현한 피보나치 수열(3)

counter = 0 

def fibonacci(n):
    counter += 1

    if n == 1:
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)
    
print(fibonacci(10))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 15
#      12     else:
#      13         return fibonacci(n - 1) + fibonacci(n - 2)
# ---> 15 print(fibonacci(10))
#
# Cell In[8], line 6, in fibonacci(n)
#       5 def fibonacci(n):
# ----> 6     counter += 1
#       8     if n == 1:
#       9         return 1
#
# UnboundLocalError: local variable 'counter' referenced before assignment

# %% [markdown]
# 파이썬은 함수 내부에서 함수 외부에 있는 변수를 참조하지 못함<br>
# 함수 내부에서 함수 외부에 있는 변수라는 것을 설명하려면 global 키워드를 사용해야 함

# %%
# 메모화

dictionary = {
    1: 1, 
    2: 1
}

def fibonacci(n):
    if n in dictionary:
        return dictionary[n]        # 메모가 되어 있으면 메모된 값을 리턴 
    else:
        output = fibonacci(n - 1) + fibonacci(n - 2)    # 메모가 없으면 값을 구함 
        dictionary[n] = output
        return output
        
print("fibonacci(10):", fibonacci(10))
print("fibonacci(20):", fibonacci(20))
print("fibonacci(30):", fibonacci(30))
print("fibonacci(40):", fibonacci(40))
print("fibonacci(50):", fibonacci(50))
# Out:
# fibonacci(10): 55
# fibonacci(20): 6765
# fibonacci(30): 832040
# fibonacci(40): 102334155
# fibonacci(50): 12586269025

# %% [markdown]
# - 메모 : 딕셔너리를 사용해서 한 번 계산한 값을 저장<br>
# 딕셔너리에 값이 메모되어 있으면 처리를 수행하지 않고 곧바로 메모된 값을 돌려주면서 코드의 속도를 빠르게 만듬

# %%
# 조기 리턴 
# 들여쓰기 단계를 줄여 코드를 더 쉽게 읽을 수 있게 함 

dictionary = {
    1: 1, 
    2: 1
}

def fibonacci(n):
    if n in dictionary:
        return dictionary[n]        
    
    output = fibonacci(n - 1) + fibonacci(n - 2)    
    dictionary[n] = output
    return output
        
print("fibonacci(10):", fibonacci(10))
print("fibonacci(20):", fibonacci(20))
# Out:
# fibonacci(10): 55
# fibonacci(20): 6765

# %% [markdown]
# - 리스트 평탄화 : 중첩된 리스트가 있을 때 중첩을 모두 제거하고 풀어서 1차원 리스트로 만드는 것

# %%
# 리스트 평탄화 하기 (1)

def flatten(data):
    output = []
    for item in data:
        if type(item) == list:
            output += item
        else:
            output.append(item)     # 매개 변수 하나를 리스트의 마지막 요소로 추가 
    return output

example = [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
print("원본: ", example)
print("변환: ", flatten(example))
# Out:
# 원본:  [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
# 변환:  [1, 2, 3, 4, [5, 6], 7, 8, 9]

# %%
# 리스트 평탄화 하기 (2)

def flatten(data):
    output = []
    for item in data:
        if type(item) == list:
            output += flatten(item)     # flatten()함수를 재귀적으로 호출합니다 
        else:
            output.append(item)
    return output

example = [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
print("원본: ", example)
print("변환: ", flatten(example))
# Out:
# 원본:  [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
# 변환:  [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# 1. 함수의 변수는 함수 호출마다 따로따로 만들어짐
# 2. 함수가 리턴되면 함수를 호출했던 위치로 돌아옴

# %%
# 확인문제

앉힐수있는최소사람수 = 2
앉힐수있는최대사람수 = 10
전체사람의수 = 100
memo = {}

def 문제(남은사람수, 최소사람수):       # 남은사람수를 최소사람수 이상의 그룹으로 나누는 방법
    key = str([남은사람수, 최소사람수])

    # 종료 조건
    if key in memo:
        return memo[key]
    if 남은사람수 < 0:
        return 0        # 무효이므로 0을 리턴
    if 남은사람수 == 0:
        return 1        # 유효하므로 수를 세기 위해 1을 리턴
    
    # 재귀 처리
    # 최소사람수부터 최대사람수까지 시도
    count = 0
    for i in range(최소사람수, 앉힐수있는최대사람수 + 1):
        count += 문제(남은사람수 - i, i)        # i명을 앉히고 남은 사람 분배
  
    # 메모화 처리
    memo[key] = count
    # 종료
    return count

print(문제(전체사람의수, 앉힐수있는최소사람수))
# Out:
# 437420

# %% [markdown]
# <img src="https://github.com/HANISY/Python-Study/blob/main/img/Sc20251111.png?raw=true" width="800">
