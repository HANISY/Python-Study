# %% [markdown]
# ### 6. 예외 처리
# #### 6-1. 구문 오류와 예외
#
# **구문 오류** : 프로그램 실행 전에 발생하는 오류
#
# **런타임 오류** : 예외, 프로그램 실행 중에 발생하는 오류
# - 조건문을 사용하는 방법
# - try 구문을 사용하는 방법

# %%
# 예외가 발생할 수 있는 코드 
number_input_a = int(input("정수 입력> "))      # 정수로 변환할 수 없는 문자열을 입력 

print("원의 반지름:", number_input_a)
print("원의 둘레:", 2 * 3.14 * number_input_a)
print("원의 넓이:", 3.14 * number_input_a * number_input_a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 2
#       1 # 예외가 발생할 수 있는 코드
# ----> 2 number_input_a = int(input("정수 입력> "))      # 정수로 변환할 수 없는 문자열을 입력
#       4 print("원의 반지름:", number_input_a)
#       5 print("원의 둘레:", 2 * 3.14 * number_input_a)
#
# ValueError: invalid literal for int() with base 10: '7센티미터'

# %%
# 조건문으로 예외 처리하기

user_input_a = input("정수 입력> ")

if user_input_a.isdigit():      # 사용자의 입력이 숫자로 구성되어 있는지 확인
    number_input_a = int(user_input_a)      # 숫자로 변환
    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2 * 3.14 * number_input_a)
    print("원의 넓이:", 3.14 * number_input_a * number_input_a)
else:
    print("정수를 입력하지 않았습니다.")
# Out:
# 정수를 입력하지 않았습니다.

# %%
try:
    예외가 발생할 가능성이 있는 코드
except:

# %%
try:
    number_input_a = int(input("정수 입력> "))
    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2 * 3.14 * number_input_a)
    print("원의 넓이:", 3.14 * number_input_a * number_input_a)
except:
    print("무언가 잘못되었습니다.")
# Out:
# 무언가 잘못되었습니다.

# %%
try:
    예외가 발생할 가능성이 있는 코드
except:
    pass        # 구문 내부에 아무 것도 넣지 않으면 구문 오류가 발생

# %%
# 숫자로 변환되는 것들만 리스트에 넣기
list_input_a = ["52", "273", "32", "스파이", "103"]

list_number = []
for item in list_input_a:
    try:
        float(item)
        list_number.append(item)        # 예외가 없으면 리스트에 추가 
    except:
        pass
    
print("{} 내부에 있는 숫자는".format(list_input_a))
print("{}입니다.".format(list_number))
# Out:
# ['52', '273', '32', '스파이', '103'] 내부에 있는 숫자는
# ['52', '273', '32', '103']입니다.

# %%
try:
    예외가 발생할 가능성이 있는 코드
except:
    예외가 발생했을 때 실행할 코드 
else:
    예외가 발생하지 않았을 때 실행할 코드

# %%
try: 
    number_input_a = int(input("정수 입력> "))
except:
    print("정수를 입력하지 않았습니다.")
else:
    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2 * 3.14 * number_input_a)
    print("원의 넓이:", 3.14 * number_input_a * number_input_a)
# Out:
# 정수를 입력하지 않았습니다.

# %%
try:
    예외가 발생할 가능성이 있는 코드
except:
    예외가 발생했을 때 실행할 코드 
else:
    예외가 발생하지 않았을 때 실행할 코드 
finally:
    무조건 실행할 코드

# %%
try: 
    number_input_a = int(input("정수 입력> "))
    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2 * 3.14 * number_input_a)
    print("원의 넓이:", 3.14 * number_input_a * number_input_a)
except:
    print("정수를 입력하지 않았습니다.")
else:
    print("예외가 발생하지 않았습니다.")
finally:
    print("일단 프로그램이 어떻게든 끝났습니다.")
# Out:
# 정수를 입력하지 않았습니다.
# 일단 프로그램이 어떻게든 끝났습니다.

# %% [markdown]
# **try** : 단독으로 사용할 수 없으며, 반드시 **except** 구문 또는 **finally** 구문과 함께 사용
#
# **else** : 반드시 **except** 구문 뒤에 사용

# %%
# try + else -- 구문 오류 발생
try: 
    number_input_a = int(input("정수 입력> "))
    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2 * 3.14 * number_input_a)
    print("원의 넓이:", 3.14 * number_input_a * number_input_a)
else:
    ("프로그램이 정상적으로 종료되었습니다.")
# Out:
#   Cell In[42], line 7
#     else:
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %% [markdown]
# 사용 가능한 조합
# - try + except
# - try + except + else
# - try + except + finally
# - try + except + else + finally
# - try + finally

# %%
# 파일이 제대로 닫혔는지 확인
try:
    # 파일을 엽니다. 
    file = open("info.txt", "w")
    # 여러 가지 처리를 수행합니다. 
    # 파일을 닫습니다. 
    file.close()
except:
    print("오류가 발생했습니다. ")

print("# 파일이 제대로 닫혔는지 확인하기")
print("file.closed:", file.closed)
# Out:
# # 파일이 제대로 닫혔는지 확인하기
# file.closed: True

# %% [markdown]
# **데몬(daemon), 서비스(service)** : 항상 켜져 있는 프로그램
#
# 컴퓨터의 성능을 감시하는 프로그램, 파일의 변경을 감시하는 프로그램, 사용자에게 웹페이지를 제공해 주는 웹 서버 등

# %%
# 파일 처리 중간에 예외 발생
try:
    file = open("info.txt", "w")
    예외.발생해라()     # 일부러 예외 발생 
    file.close()
except:
    print("오류가 발생했습니다.")

print("# 파일이 제대로 닫혔는지 확인하기")
print("file.closed:", file.closed)
# Out:
# 오류가 발생했습니다.
# # 파일이 제대로 닫혔는지 확인하기
# file.closed: False

# %%
# finallly 구문을 사용하여 파일 닫기 
try:
    file = open("info.txt", "w")
    예외.발생해라()     # 일부러 예외 발생 
except:
    print("오류가 발생했습니다.")
finally:
    file.close()

print("# 파일이 제대로 닫혔는지 확인하기")
print("file.closed:", file.closed)
# Out:
# 오류가 발생했습니다.
# # 파일이 제대로 닫혔는지 확인하기
# file.closed: True

# %%
# try except 구문 끝난 후 파일 닫기
try:
    file = open("info.txt", "w")
    예외.발생해라()     # 일부러 예외 발생 
except:
    print("오류가 발생했습니다.")
    
file.close()
print("# 파일이 제대로 닫혔는지 확인하기")
print("file.closed:", file.closed)
# Out:
# 오류가 발생했습니다.
# # 파일이 제대로 닫혔는지 확인하기
# file.closed: True

# %% [markdown]
# → finally키워드는 어떤 조건에 무조건 사용해야하는 것이 아니라, 사용하면 코드가 깔끔해질 것 같다고 생각되는 경우에 사용

# %%
# try 구문 내부에서 return 키워드를 사용하는 경우 
def test():
    print("test() 함수의 첫 줄입니다.")
    try:
        print("try 구문이 실행되었습니다.")
        return
        print("try 구문의 return 키워드 뒤입니다.")
    except:
        print("except 구문이 실행되었습니다.")
    else:
        print("else 구문이 실행되었습니다.")
    finally:
        print("finally 구문이 실행되었습니다.")
    print("test() 함수의 마지막 줄입니다.")

test()
# Out:
# test() 함수의 첫 줄입니다.
# try 구문이 실행되었습니다.
# finally 구문이 실행되었습니다.

# %% [markdown]
# → return 키워드를 이용해 try 구문 중간에서 탈출해도 finally 구문은 무조건 실행

# %%
def write_text_file(filename, text):
    try:
        file = open(filename, "w")
        return
        file.write(text)        # 파일에 텍스트를 입력합니다. 
    except:
        print("오류가 발생했습니다.")
    finally:
        file.close()

write_text_file("test.txt", "안녕하세요!")

# %%
# 반복문과 함께 사용하는 경우 
print("프로그램이 시작되었습니다.")

while True:
    try:
        print("try 구문이 실행되었습니다.")
        break
        print("try 구문의 break 뒤입니다.")
    except:
        print("except 구문이 실행되었습니다.")
    finally:
        print("finally 구문이 실행되었습니다.")
    print("while 반복문의 마지막 줄입니다.")

print("프로그램이 종료되었습니다.")
# Out:
# 프로그램이 시작되었습니다.
# try 구문이 실행되었습니다.
# finally 구문이 실행되었습니다.
# 프로그램이 종료되었습니다.

# %%
numbers = [52, 273, 32, 103, 90, 10, 275]
numbers.index(32)       # 리스트 내부에서 특정 값의 위치 확인
# Out:
# 2

# %%
numbers = [1, 1, 1, 1, 1]
numbers.index(1)        # 해당 값이 여러 개 있을 경우 첫 번째 값의 위치를 리턴
# Out:
# 0

# %%
numbers = [52, 273, 32, 103, 90, 10, 275]
numbers.index(10000000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 2
#       1 numbers = [52, 273, 32, 103, 90, 10, 275]
# ----> 2 numbers.index(10000000)
#
# ValueError: 10000000 is not in list

# %%
# try except 구문 사용 
numbers = [52, 273, 32, 103, 90, 10, 275]

print("# (1) 요소 내부에 있는 값 찾기")
print("- {}는 {} 위치에 있습니다.".format(52, numbers.index(52)))
print()

print("# (2) 요소 내부에 없는 값 찾기")
number = 10000
try:
    print("- {}는 {} 위치에 있습니다.".format(number, numbers.index(number)))
except:
    print("- 리스트 내부에 없는 값입니다.")
print()

print("---정상적으로 종료되었습니다.")
# Out:
# # (1) 요소 내부에 있는 값 찾기
# - 52는 0 위치에 있습니다.
#
# # (2) 요소 내부에 없는 값 찾기
# - 리스트 내부에 없는 값입니다.
#
# ---정상적으로 종료되었습니다.

# %%
# 조건문 사용 
numbers = [52, 273, 32, 103, 90, 10, 275]

print("# (1) 요소 내부에 있는 값 찾기")
print("- {}는 {} 위치에 있습니다.".format(52, numbers.index(52)))
print()

print("# (2) 요소 내부에 없는 값 찾기")
number = 10000
if number in numbers:
    print("- {}는 {} 위치에 있습니다.".format(number, numbers.index(number)))
else:
    print("- 리스트 내부에 없는 값입니다.")
print()

print("---정상적으로 종료되었습니다.")
# Out:
# # (1) 요소 내부에 있는 값 찾기
# - 52는 0 위치에 있습니다.
#
# # (2) 요소 내부에 없는 값 찾기
# - 리스트 내부에 없는 값입니다.
#
# ---정상적으로 종료되었습니다.

# %% [markdown]
# #### 6-2. 예외 고급

# %%
try:
    예외가 발생할 가능성이 있는 구문
except 예외의 종류 as 예외 객체를 활용할 변수 이름:
    예외가 발생했을 때 실행할 구문

# %%
try:
    number_input_a = int(input("정수 입력> "))
    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2 * 3.14 * number_input_a)
    print("원의 넓이:", 3.14 * number_input_a * number_input_a)
except Exception as exception:
    print("type(exception):", type(exception))
    print("exception:", exception)
# Out:
# type(exception): <class 'ValueError'>
# exception: invalid literal for int() with base 10: 'test'

# %% [markdown]
# ※ 예외가 발생할 때 이러한 정보를 메일 등으로 보내도록 해서 수집하면 이후에 프로그램을 개선하는 데 큰 도움이 됨

# %%
# 정수로 변환될 수 없는 값을 입력한 경우 - ValueError 발생 

list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))
except Exception as exception:
    print("type(exception):", type(exception))
    print("exception:", exception)
# Out:
# type(exception): <class 'ValueError'>
# exception: invalid literal for int() with base 10: 'test'

# %%
# 리스트의 길이를 넘는 인덱스를 입력한 경우 - IndexError 발생

list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))
except Exception as exception:
    print("type(exception):", type(exception))
    print("exception:", exception)
# Out:
# type(exception): <class 'IndexError'>
# exception: list index out of range

# %%
try:
    예외가 발생할 가능성이 있는 구문
except 예외의 종류A:
    예외A가 발생했을 때 실행할 구문
except 예외의 종류B:
    예외B가 발생했을 때 실행할 구문
except 예외의 종류C:
    예외C가 발생했을 때 실행할 구문

# %%
# 예외 구분하기
list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))
except ValueError:              # 대소문자 구분 필수 
    print("정수를 입력해 주세요!")
except IndexError:
    print("리스트의 인덱스를 벗어났어요!")
# Out:
# 정수를 입력해 주세요!

# %%
# 예외 구문과 예외 객체 
# 예외 객체 : 예외 정보를 저장
list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))
except ValueError as exception:
    # ValueError가 발생하는 경우 
    print("정수를 입력해 주세요!")
    print("exception:", exception)
except IndexError as exception:
    # IndexError가 발생하는 경우
    print("리스트의 인덱스를 벗어났어요!") 
    print("exception:", exception)
# Out:
# 리스트의 인덱스를 벗어났어요!
# exception: list index out of range

# %%
# 예외 처리를 했지만 예외를 못잡는 경우 
# 예외 조건에 일치하는 것이 없다면 프로그램이 강제 종료 
list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))
    예외.발생해주세요()             # 잡지 않은 예외가 발생하는 부분
except ValueError as exception:
    # ValueError가 발생하는 경우 
    print("정수를 입력해 주세요!")
    print("exception:", exception)
except IndexError as exception:
    # IndexError가 발생하는 경우
    print("리스트의 인덱스를 벗어났어요!") 
    print("exception:", exception)
# Out:
# 1번째 요소: 273
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 8
#       6     number_input = int(input("정수 입력> "))
#       7     print("{}번째 요소: {}".format(number_input, list_number[number_input]))
# ----> 8     예외.발생해주세요()
#       9 except ValueError as exception:
#      10     # ValueError가 발생하는 경우
#      11     print("정수를 입력해 주세요!")
#
# NameError: name '예외' is not defined

# %%
# 모든 예외 잡기 
list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))
    예외.발생해주세요()             # 잡지 않은 예외가 발생하는 부분
except ValueError as exception:
    # ValueError가 발생하는 경우 
    print("정수를 입력해 주세요!")
    print("exception:", exception)
except IndexError as exception:
    # IndexError가 발생하는 경우
    print("리스트의 인덱스를 벗어났어요!") 
    print("exception:", exception)
except Exception as exception:
    # 이외의 예외가 발생하는 경우
    print("미리 파악하지 못한 예외가 발생했습니다.")
    print(type(exception), exception)
# Out:
# 1번째 요소: 273
# 미리 파악하지 못한 예외가 발생했습니다.
# <class 'NameError'> name '예외' is not defined

# %% [markdown]
# **raise**: 예외를 강제로 발생시키는 명령문
#
# 잘못된 조건을 감지하면 코드 실행을 중단
#
# 에러 메시지로 문제 상황을 명확히 표현
#
# try-except와 함께 안정적인 오류 처리 구조 구성 가능

# %%
# 아직 구현되지 않은 부분에서 강제로 예외 발생시키기
number = input("정수 입력> ")
number = int(number)

if number > 0:
    # 양수일 때: 아직 미구현 상태입니다. 
    raise NotImplementedError
else:
    # 음수일 때: 아직 미구현 상태입니다.
    raise NotImplementedError
